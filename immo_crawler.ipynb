# %%
from bs4 import BeautifulSoup
import time
import requests
from fake_useragent import UserAgent
import random
import pandas as pd
import re
from tqdm import tqdm
import sqlite3
import datetime
import numpy as np
import multiprocessing
from pebble import ProcessPool
from concurrent.futures import TimeoutError



#######################################
# get already known Expose IDs from DB
#######################################

conn = sqlite3.connect("sqlite/realty.db")
c = conn.cursor()
try:
    c.execute("SELECT distinct id FROM realties;")
    x = c.fetchall()
    known_expose_ids = [i[0] for i in x]
except:
    known_expose_ids = []
conn.close()

print('Currently there are ', len(known_expose_ids), 'realties stored in DB.')



#######################################
# define helper functions
#######################################

def get_proxies():
    from lxml.html import fromstring
    import requests

    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies_http = []
    proxies_https = []
    for i in parser.xpath('//tbody/tr'):
        if i.xpath('.//td[7]/text()') == ['no']:
            if i.xpath('.//td[5]/text()')==['elite proxy']:# and i.xpath('.//td[3]/text()') == ['DE']:
                #Grabbing IP and corresponding PORT
                http = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
                proxies_http.append(http)
        if i.xpath('.//td[7]/text()') == ['yes']:
            if i.xpath('.//td[5]/text()')==['elite proxy']:# and i.xpath('.//td[3]/text()') == ['DE']:
                #Grabbing IP and corresponding PORT
                https = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
                proxies_https.append(https)

    return proxies_http, proxies_https







def get_soup(ua, url, proxies, echo=False):
    bad_proxies = []
    headers = {'User-Agent': ua.random}
    proxy = proxies[random.randrange(len(proxies))]
    if echo:
        print('scraping:', url)
        
    try:
        r  = requests.get(url, headers=headers, proxies=proxy)

    except requests.exceptions.ProxyError:
        if echo:
            print('trying different Proxy')
            
        bad_proxies.append(proxy)
        proxy = proxies[random.randrange(len(proxies))]
        try:
            r  = requests.get(url, headers=headers, proxies=proxy)
        except:
            try:
                r  = requests.get(url, headers=headers)
            except:
                pass
    except:
        try:
            r  = requests.get(url, headers=headers)
        except:
            pass

    data = r.text
    soup = BeautifulSoup(data, "lxml")
    return soup, bad_proxies




def parallelize_function(url_list, func):
    
    start_ts = datetime.datetime.now()
  
    num_cores = multiprocessing.cpu_count()-1  #leave one free to not freeze machine
    print('processing function on', num_cores, 'cores...')
    pool = multiprocessing.Pool(num_cores)
    results = pool.map(func, url_list)
    pool.close()
    pool.join()
    
    print('Finished parallell processing after', datetime.datetime.now() - start_ts, 'seconds')
    
    return results


def parallelize_function_timeout(urls, func):
    with ProcessPool() as pool:
        future = pool.map(func, urls, timeout=90)

        iterator = future.result()
        result = pd.DataFrame()
        while True:
            try:
                result = result.append(next(iterator))
            except StopIteration:
                break
            except TimeoutError as error:
                print("scraping took longer than %d seconds" % error.args[1])
        return result


def scrape_meta_chunk(url, return_soup=False):
    print(url)
    # scrape next url
    soup, bad_proxies = get_soup(ua, url, proxies)

    # remove bad proxies from list
    if len(bad_proxies) > 0:
        try:
            proxies.remove(bad_proxies)
        except:
            pass

    
    try:
        
        data = pd.DataFrame(
            [
            [location['data-result-id'], 
             location.getText().split(', ')[-1], 
             location.getText().split(', ')[-2], 
             location.getText().split(', ')[-3] if len(location.getText().split(', ')) == 3 else '', 
             str(datetime.datetime.now())] 
            for location in 
            soup.findAll("button", {"class": "button-link link-internal result-list-entry__map-link", "title": "Auf der Karte anzeigen"})], columns=['id','city_county', 'city_quarter', 'street', 'scraped_ts']
        )
        #data = pd.DataFrame({'id':expose_list,'city_county':city_county, 'city_quarter': city_quarter, 'street':street, 'scraped_ts': str(datetime.datetime.now())})
        
    except Exception as err:
        print(url, err)
        data = pd.DataFrame()
    if return_soup:
        return data, soup
    else:
        return data



def scrape_details_chunk(realty):
        
    expose_id = []
    title = []
    realty_type = []
    floor = []
    square_m = []
    storage_m = []
    num_rooms = []
    num_bedrooms = []
    num_baths = []
    num_carparks = []
    year_built = []
    last_refurb= []
    quality = []
    heating_type = []
    fuel_type = []
    energy_consumption = []
    energy_class = []
    net_rent = []
    gross_rent = []
    
    
    #for realty in chunk:
        
    url = 'https://www.immobilienscout24.de/expose/' + realty
    print(url)
    soup, bad_proxies = get_soup(ua, url, proxies)

    expose_id.append(realty)
    title.append(soup.find('title').getText())

    if soup.find('dd', {'class':"is24qa-typ grid-item three-fifths"}):
        realty_type.append(soup.find('dd', {'class':"is24qa-typ grid-item three-fifths"}).getText().replace(' ', ''))
    else:
        realty_type.append(0)

    if soup.find('dd', {'class':"is24qa-etage grid-item three-fifths"}):
        floor.append(soup.find('dd', {'class':"is24qa-etage grid-item three-fifths"}).getText())
    else:
        floor.append(0)

    if soup.find('dd', {'class':"is24qa-wohnflaeche-ca grid-item three-fifths"}):
        square_m.append(soup.find('dd', {'class':"is24qa-wohnflaeche-ca grid-item three-fifths"}).getText().replace(' ', '').replace('m²', ''))
    else:
        square_m.append(0)

    if soup.find('dd', {'class':"is24qa-nutzflaeche-ca grid-item three-fifths"}):
        storage_m.append(soup.find('dd', {'class':"is24qa-nutzflaeche-ca grid-item three-fifths"}).getText().replace(' ', '').replace('m²', ''))
    else:
        storage_m.append(0)

    if soup.find('dd', {'class':"is24qa-zimmer grid-item three-fifths"}):
        num_rooms.append(soup.find('dd', {'class':"is24qa-zimmer grid-item three-fifths"}).getText().replace(' ', ''))
    else:
         num_rooms.append(0)

    if soup.find('dd', {'class':"is24qa-schlafzimmer grid-item three-fifths"}):
        num_bedrooms.append(soup.find('dd', {'class':"is24qa-schlafzimmer grid-item three-fifths"}).getText().replace(' ', ''))
    else:
        num_bedrooms.append(0)

    if soup.find('dd', {'class':"is24qa-badezimmer grid-item three-fifths"}):
        num_baths.append(soup.find('dd', {'class':"is24qa-badezimmer grid-item three-fifths"}).getText().replace(' ', ''))
    else:
        num_baths.append(0)

    if soup.find('dd', {'class':"is24qa-garage-stellplatz grid-item three-fifths"}):
        num_carparks.append(re.sub('[^0-9]', '', soup.find('dd', {'class':"is24qa-garage-stellplatz grid-item three-fifths"}).getText()))
    else:
        num_carparks.append(0)

    if soup.find('div', {'class':"is24qa-kaltmiete is24-value font-semibold"}):
        net_rent.append(re.sub('[^0-9]', '', soup.find('div', {'class':"is24qa-kaltmiete is24-value font-semibold"}).getText()))
    else:
        net_rent.append(0)

    if soup.find('dd', {'class':"is24qa-baujahr grid-item three-fifths"}):
        year_built.append(soup.find('dd', {'class':"is24qa-baujahr grid-item three-fifths"}).getText())
    else:
        year_built.append(0)

    if soup.find('dd', {'class':"is24qa-modernisierung-sanierung grid-item three-fifths"}):
        last_refurb.append(soup.find('dd', {'class':"is24qa-modernisierung-sanierung grid-item three-fifths"}).getText())
    else:
        last_refurb.append(0)

    if soup.find('dd', {'class':"is24qa-qualitaet-der-ausstattung grid-item three-fifths"}):
        quality.append(soup.find('dd', {'class':"is24qa-qualitaet-der-ausstattung grid-item three-fifths"}).getText().strip())
    else:
        quality.append(0)

    if soup.find('dd', {'class':"is24qa-heizungsart grid-item three-fifths"}):
        heating_type.append(soup.find('dd', {'class':"is24qa-heizungsart grid-item three-fifths"}).getText().strip())
    else:
        heating_type.append(0)

    if soup.find('dd', {'class':"is24qa-wesentliche-energietraeger grid-item three-fifths"}):
        fuel_type.append(soup.find('dd', {'class':"is24qa-wesentliche-energietraeger grid-item three-fifths"}).getText().strip())
    else:
        fuel_type.append(0)

    if soup.find('dd', {'class':"is24qa-endenergiebedarf grid-item three-fifths"}):
        energy_consumption.append(soup.find('dd', {'class':"is24qa-endenergiebedarf grid-item three-fifths"}).getText().strip())
    else:
        energy_consumption.append(0)

    if soup.find('dd', {'class':"is24qa-energieeffizienzklasse grid-item three-fifths"}):
        energy_class.append(soup.find('dd', {'class':"is24qa-energieeffizienzklasse grid-item three-fifths"}).getText().strip())
    else:
        energy_class.append(0)

    if soup.find('dd', {'class':"is24qa-gesamtmiete grid-item three-fifths font-bold"}):
        gross_rent.append(soup.find('dd', {'class':"is24qa-gesamtmiete grid-item three-fifths font-bold"}).getText().strip().replace(' €',''))
    else:
        gross_rent.append(0)

    if len(bad_proxies) > 0:
        try:
            proxies.remove(bad_proxies)
        except:
            pass
        
    results = pd.DataFrame({
    'id': expose_id,
    'title': title, 
    'realty_type': realty_type, 
    'floor': floor,
    'square_m': square_m,
    'storage_m': storage_m, 
    'num_rooms': num_rooms, 
    'num_bedrooms': num_bedrooms,
    'num_baths': num_baths,
    'num_carparks': num_carparks, 
    'year_built': year_built, 
    'last_refurb': last_refurb,
    'quality': quality,
    'heating_type': heating_type, 
    'fuel_type': fuel_type, 
    'energy_consumption': energy_consumption,
    'energy_class': energy_class,
    'net_rent': net_rent, 
    'gross_rent': gross_rent,
    'scraped_ts': str(datetime.datetime.now())
    })
    
    return results




proxies_http, proxies_https = get_proxies()
proxies = [{'http': http} for http in proxies_http] + [{'https': https} for https in proxies_https]

ua = UserAgent(fallback='Mozilla/5.0 (compatible; Googlebot/2.1; ')
# Out:
# Currently there are  2364 realties stored in DB.

# %%
#######################################
# scrape proxies and User Agents lists
#######################################

proxies_http, proxies_https = get_proxies()
proxies = [{'http': http} for http in proxies_http] + [{'https': https} for https in proxies_https]

ua = UserAgent(fallback='Mozilla/5.0 (compatible; Googlebot/2.1; ')





#######################################
# Crawl first page:
#######################################
url = 'https://www.immobilienscout24.de/Suche/S-T/P-1/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30'


realty_meta_df, soup = scrape_meta_chunk(url,return_soup=True)
num_pages = len(soup.find_all('option'))
print('scraped', len(realty_meta_df), 'realties on first page')
print('found', num_pages, 'pages to scrape')
# Out:
# https://www.immobilienscout24.de/Suche/S-T/P-1/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# scraped 20 realties on first page
# found 100 pages to scrape

# %%
#######################################
# Crawl next pages:
#######################################


realty_meta_urls = ['https://www.immobilienscout24.de/Suche/S-T/P-' + str(page) + '/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30' for page in range(2, num_pages + 1)]
realty_meta_df = realty_meta_df.append(parallelize_function_timeout(realty_meta_urls, scrape_meta_chunk))
#realty_meta_df = pd.concat(realty_meta, ignore_index=True)
print('Done')
# Out:
# https://www.immobilienscout24.de/Suche/S-T/P-2/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-3/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-4/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-5/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-6/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-7/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-8/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-9/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-10/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-11/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-12/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-13/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-15/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-14/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-16/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-19/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-17/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-20/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-18/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-21/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-22/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-23/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-24/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-25/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-26/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-27/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-28/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-29/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-30/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-31/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-32/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-33/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-34/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-35/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-36/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-37/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-38/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-39/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-40/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-41/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-42/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-43/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-44/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-45/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-46/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-47/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-48/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-49/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-50/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-51/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-52/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-53/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-54/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-55/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-56/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-57/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-58/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-59/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-60/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-61/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-62/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-63/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-64/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-65/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-66/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-67/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-68/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-69/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-70/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-71/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-72/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-73/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-74/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-75/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-76/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-77/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-78/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-79/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-80/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-81/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-82/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-83/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-84/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-85/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-86/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-87/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-88/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-89/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-90/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-91/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-92/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-93/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-94/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-95/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-96/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-97/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-98/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-99/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# https://www.immobilienscout24.de/Suche/S-T/P-100/Wohnung-Miete/Umkreissuche/Hamburg/-/1840/2621814/-/-/30
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# Done

# %%
# drop known exposes:
#######################################



print('removing', len(realty_meta_df.loc[pd.to_numeric(realty_meta_df.id).isin(known_expose_ids)]), 'already scraped Exposes from list.')
realty_meta_df = realty_meta_df.loc[~pd.to_numeric(realty_meta_df.id).isin(known_expose_ids)] #realty_meta_df.loc[~realty_meta_df.id.isin(known_expose_ids)]
realty_meta_df = realty_meta_df.drop_duplicates()
realty_meta_df = realty_meta_df.reset_index(drop=True)
print(len(realty_meta_df), 'realties left.')
# Out:
# removing 1753 already scraped Exposes from list.
# 68 realties left.

# %%
#######################################
# scrape each expose page:
#######################################




expose_id = []
title = []
realty_type = []
floor = []
square_m = []
storage_m = []
num_rooms = []
num_bedrooms = []
num_baths = []
num_carparks = []
year_built = []
last_refurb= []
quality = []
heating_type = []
fuel_type = []
energy_consumption = []
energy_class = []
net_rent = []
gross_rent = []


realty_details = pd.DataFrame(columns=[
    'expose_id',
    'title', 
    'realty_type', 
    'floor',
    'square_m',
    'storage_m', 
    'num_rooms', 
    'num_bedrooms',
    'num_baths',
    'num_carparks', 
    'year_built', 
    'last_refurb',
    'quality',
    'heating_type', 
    'fuel_type', 
    'energy_consumption',
    'energy_class',
    'net_rent', 
    'gross_rent'
])




# multi core scraping
#######################################

realties = list(set(list(realty_meta_df.id)))
print('scraping', len(realties), 'realties...')
realty_details_df = parallelize_function_timeout(realties, scrape_details_chunk)
#realty_details_df = pd.concat(realty_details, ignore_index=True)
realty_details_df = realty_details_df.drop_duplicates()
realty_details_df = realty_details_df.reset_index(drop=True)
print('scraped', len(realty_details_df), 'realties.')
# Out:
# scraping 67 realties...
# https://www.immobilienscout24.de/expose/111433042
# https://www.immobilienscout24.de/expose/111496116
# https://www.immobilienscout24.de/expose/110001854
# https://www.immobilienscout24.de/expose/110235533
# https://www.immobilienscout24.de/expose/111506457
# https://www.immobilienscout24.de/expose/111495800
# https://www.immobilienscout24.de/expose/111499333
# https://www.immobilienscout24.de/expose/84519374
# https://www.immobilienscout24.de/expose/111505587
# https://www.immobilienscout24.de/expose/97631041
# https://www.immobilienscout24.de/expose/79631216
# https://www.immobilienscout24.de/expose/111511638
# https://www.immobilienscout24.de/expose/99768824
# https://www.immobilienscout24.de/expose/111507441
# https://www.immobilienscout24.de/expose/111509814
# https://www.immobilienscout24.de/expose/111504301
# https://www.immobilienscout24.de/expose/111501933
# https://www.immobilienscout24.de/expose/111499468
# https://www.immobilienscout24.de/expose/111509658
# https://www.immobilienscout24.de/expose/111494250
# https://www.immobilienscout24.de/expose/111498614
# https://www.immobilienscout24.de/expose/41602064
# https://www.immobilienscout24.de/expose/111503111
# https://www.immobilienscout24.de/expose/111501684
# https://www.immobilienscout24.de/expose/111497150
# https://www.immobilienscout24.de/expose/111500916
# https://www.immobilienscout24.de/expose/108914849
# https://www.immobilienscout24.de/expose/111506349
# https://www.immobilienscout24.de/expose/111503752
# https://www.immobilienscout24.de/expose/107316418
# https://www.immobilienscout24.de/expose/111478541
# https://www.immobilienscout24.de/expose/107332027
# https://www.immobilienscout24.de/expose/111511217
# https://www.immobilienscout24.de/expose/111476961
# https://www.immobilienscout24.de/expose/111498609
# https://www.immobilienscout24.de/expose/111495984
# https://www.immobilienscout24.de/expose/111179685
# https://www.immobilienscout24.de/expose/111477882
# https://www.immobilienscout24.de/expose/97630578
# https://www.immobilienscout24.de/expose/97630596
# https://www.immobilienscout24.de/expose/111499595
# https://www.immobilienscout24.de/expose/111504845
# https://www.immobilienscout24.de/expose/111504776
# https://www.immobilienscout24.de/expose/111495615
# https://www.immobilienscout24.de/expose/111498605
# https://www.immobilienscout24.de/expose/111497520
# https://www.immobilienscout24.de/expose/111434448
# https://www.immobilienscout24.de/expose/111479177
# https://www.immobilienscout24.de/expose/97013899
# https://www.immobilienscout24.de/expose/61328880
# https://www.immobilienscout24.de/expose/111496828
# https://www.immobilienscout24.de/expose/97630812
# https://www.immobilienscout24.de/expose/111497333
# https://www.immobilienscout24.de/expose/111498355
# https://www.immobilienscout24.de/expose/111496726
# https://www.immobilienscout24.de/expose/111497504
# https://www.immobilienscout24.de/expose/111496856
# https://www.immobilienscout24.de/expose/111501485
# https://www.immobilienscout24.de/expose/111042649
# https://www.immobilienscout24.de/expose/111054474
# https://www.immobilienscout24.de/expose/38396901
# https://www.immobilienscout24.de/expose/94159357
# https://www.immobilienscout24.de/expose/89096871
# https://www.immobilienscout24.de/expose/111505381
# https://www.immobilienscout24.de/expose/54587588
# https://www.immobilienscout24.de/expose/88905716
# https://www.immobilienscout24.de/expose/111509241
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraping took longer than 90 seconds
# scraped 62 realties.

# %%
realty_meta_df['id'] = realty_meta_df['id'].astype(int)
realty_details_df['id'] = realty_details_df['id'].astype(int)

final_data = realty_meta_df.drop('scraped_ts',axis = 1).merge(realty_details_df, on='id', suffixes = ['_meta', '_details'])

# %%
final_data.head()
# Out:
#           id city_county city_quarter                     street  \
# 0  111506349     Hamburg  Hammerbrook               Nagelsweg 24
# 1   38396901     Hamburg        Sasel              Gilcherweg 53
# 2  111497150     Hamburg   Rotherbaum           Grindelallee 128
# 3  111497333     Hamburg    Allermöhe  Wilhelmine-Hundert-Weg 22
# 4  111499468     Hamburg  Nienstedten
#
#                                                title         realty_type  \
# 0  Erstbezug: freundliche 2-Zimmer-Wohnung in Fle...       Etagenwohnung
# 1  Helle und ruhige 2-Z-EG-Wohnung im grünen Gilc...  Erdgeschosswohnung
# 2                    Alster, Villen und Campus-Leben       Etagenwohnung
# 3      2-Zimmer-Wohnung in schöner Lage in Allermöhe                   0
# 4  Sehr großzügig geschnittene Wohnung mit Fahrst...       Etagenwohnung
#
#        floor square_m storage_m num_rooms             ...              \
# 0   6 von 7        53         0         2             ...
# 1          0       65         0         2             ...
# 2   4 von 4        75        75         2             ...
# 3         2     58,65         0         2             ...
# 4          0      232         0         6             ...
#
#   year_built     last_refurb            quality    heating_type  fuel_type  \
# 0       2018               0  Gehobene Qualität               0          0
# 1       2001   zuletzt 2019   Gehobene Qualität     Gas-Heizung        Gas
# 2       1957   zuletzt 2019   Gehobene Qualität  Zentralheizung  Fernwärme
# 3       1996               0                  0               0  Fernwärme
# 4       2000               0  Gehobene Qualität  Zentralheizung         Öl
#
#   energy_consumption energy_class net_rent gross_rent  \
# 0    55,8 kWh/(m²*a)            B     1090      1.255
# 1     107 kWh/(m²*a)            0      845      1.030
# 2                  0            0     1125      1.285
# 3                  0            0      550        764
# 4                  0            D     2900      3.500
#
#                    scraped_ts
# 0  2019-05-15 10:05:01.431649
# 1  2019-05-15 10:05:07.701545
# 2  2019-05-15 10:05:01.425807
# 3  2019-05-15 10:05:02.506332
# 4  2019-05-15 10:05:00.922233
#
# [5 rows x 23 columns]

# %%
print(len(final_data))
# Out:
# 63

# %%
#######################################
# write to sqlite3
#######################################


print('Writing results to DB.')
conn = sqlite3.connect("sqlite/realty.db")

final_data.to_sql('realties', conn, if_exists ='append')

conn.close()
print('done.')
# Out:
# Writing results to DB.
# done.
